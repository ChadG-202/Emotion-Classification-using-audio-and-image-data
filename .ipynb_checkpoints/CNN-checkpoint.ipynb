# %%
# Imports
import librosa, librosa.display
import matplotlib.pyplot as plt
import os
import numpy as np
import math
import json
import cv2
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

# %%
# Load data
DATA_PATH = "json_storage/data.json"
IMG_SIZE = 48

def load_audio_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)
        
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

def load_image_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)
        
    X = np.array(data["image"]).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    y = np.array(data["labels"])
    return X, y

# %%
# Split data
def prepare_datasets(validation_size, X, y, A_type):

    X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=validation_size)

    if(A_type):
        X_train = X_train[..., np.newaxis]
        X_validation = X_validation[..., np.newaxis]
        X_test = X_test[..., np.newaxis]
    
    return X_train, X_validation, y_train, y_validation

# %%
# CNN model
def build_model(input_shape):
    model = keras.Sequential()
    
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))                                
    model.add(keras.layers.Dropout(0.25))  
    
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(64, (3, 3), activation='relu'))   
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))                                
    model.add(keras.layers.Dropout(0.25))
    
    model.add(keras.layers.Flatten())
        
    model.add(keras.layers.Dense(256, activation='relu'))
    model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(480, activation='relu'))
    model.add(keras.layers.Dropout(0.05))
    
    model.add(keras.layers.Dense(3, activation='softmax'))
    
    return model

# %%
# Train/Test Split data
validation_size = 0.2
test_size = 0.2

X_audio, y_audio = load_audio_data(DATA_PATH)
X_image, y_image = load_image_data(DATA_PATH)

X_audio_train, X_audio_test, X_audio_validation, y_audio_train, y_audio_test, y_audio_validation = prepare_datasets(validation_size, test_size, X_audio, y_audio, True)

X_image_train, X_image_test, X_image_validation, y_image_train, y_image_test, y_image_validation = prepare_datasets(validation_size, test_size, X_image, y_image, False)

# %%
# Audio train
audio_input_shape = (X_audio_train.shape[1], X_audio_train.shape[2], X_audio_train.shape[3])
audio_model = build_model(audio_input_shape)

audio_optimizer = keras.optimizers.Adam(learning_rate=0.0001)

audio_model.compile(optimizer=audio_optimizer,
             loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

audio_model.summary()

audio_history = audio_model.fit(X_audio_train, y_audio_train, batch_size=2, epochs=40, validation_data=(X_audio_validation, y_audio_validation))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 85, 11, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 85, 11, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 83, 9, 32)         9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 83, 9, 32)         128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 42, 5, 32)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 42, 5, 32)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 42, 5, 32)         128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 40, 3, 64)         18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 40, 3, 64)         256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 38, 1, 64)         36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 19, 1, 64)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 1, 64)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1216)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               311552
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 480)               123360
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 480)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1443
# =================================================================
# Total params: 501,987
# Trainable params: 501,667
# Non-trainable params: 320
# _________________________________________________________________
# Epoch 1/40
# 98/98 [==============================] - 2s 12ms/step - loss: 1.1942 - accuracy: 0.4359 - val_loss: 1.0028 - val_accuracy: 0.5102
# Epoch 2/40
# 98/98 [==============================] - 1s 10ms/step - loss: 1.0537 - accuracy: 0.5436 - val_loss: 0.8281 - val_accuracy: 0.6939
# Epoch 3/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.9092 - accuracy: 0.6154 - val_loss: 0.6456 - val_accuracy: 0.7959
# Epoch 4/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.6552 - accuracy: 0.7333 - val_loss: 0.4863 - val_accuracy: 0.8367
# Epoch 5/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.5452 - accuracy: 0.7744 - val_loss: 0.3197 - val_accuracy: 0.8776
# Epoch 6/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.4044 - accuracy: 0.8359 - val_loss: 0.2199 - val_accuracy: 0.9184
# Epoch 7/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.3155 - accuracy: 0.8718 - val_loss: 0.1377 - val_accuracy: 0.9592
# Epoch 8/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.1823 - accuracy: 0.9538 - val_loss: 0.1224 - val_accuracy: 0.9796
# Epoch 9/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.1695 - accuracy: 0.9436 - val_loss: 0.1029 - val_accuracy: 0.9796
# Epoch 10/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.1599 - accuracy: 0.9538 - val_loss: 0.0895 - val_accuracy: 0.9796
# Epoch 11/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0774 - accuracy: 0.9744 - val_loss: 0.0981 - val_accuracy: 0.9592
# Epoch 12/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.1389 - accuracy: 0.9436 - val_loss: 0.0525 - val_accuracy: 0.9796
# Epoch 13/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0535 - accuracy: 0.9846 - val_loss: 0.0549 - val_accuracy: 0.9796
# Epoch 14/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0934 - accuracy: 0.9590 - val_loss: 0.0661 - val_accuracy: 0.9796
# Epoch 15/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0753 - accuracy: 0.9692 - val_loss: 0.0548 - val_accuracy: 0.9796
# Epoch 16/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0448 - accuracy: 0.9846 - val_loss: 0.0455 - val_accuracy: 0.9796
# Epoch 17/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0319 - accuracy: 0.9949 - val_loss: 0.0745 - val_accuracy: 0.9796
# Epoch 18/40
# 98/98 [==============================] - 1s 10ms/step - loss: 0.0540 - accuracy: 0.9692 - val_loss: 0.0462 - val_accuracy: 0.9796
# Epoch 19/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9796
# Epoch 20/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0492 - accuracy: 0.9949 - val_loss: 0.0346 - val_accuracy: 0.9796
# Epoch 21/40
# 98/98 [==============================] - 1s 10ms/step - loss: 0.0394 - accuracy: 0.9846 - val_loss: 0.0490 - val_accuracy: 0.9796
# Epoch 22/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0276 - accuracy: 0.9949 - val_loss: 0.0977 - val_accuracy: 0.9796
# Epoch 23/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 0.9796
# Epoch 24/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 0.9796
# Epoch 25/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0302 - accuracy: 0.9846 - val_loss: 0.0761 - val_accuracy: 0.9796
# Epoch 26/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0191 - accuracy: 0.9949 - val_loss: 0.0424 - val_accuracy: 0.9796
# Epoch 27/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0444 - accuracy: 0.9846 - val_loss: 0.1168 - val_accuracy: 0.9796
# Epoch 28/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0487 - accuracy: 0.9897 - val_loss: 0.0384 - val_accuracy: 0.9796
# Epoch 29/40
# 98/98 [==============================] - 1s 10ms/step - loss: 0.0177 - accuracy: 0.9897 - val_loss: 0.0405 - val_accuracy: 0.9796
# Epoch 30/40
# 98/98 [==============================] - 1s 10ms/step - loss: 0.0191 - accuracy: 0.9897 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 31/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0308 - val_accuracy: 0.9796
# Epoch 32/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 33/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9796
# Epoch 34/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9796
# Epoch 35/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9796
# Epoch 36/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0378 - accuracy: 0.9846 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 37/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0268 - accuracy: 0.9897 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 38/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.0199 - val_accuracy: 0.9796
# Epoch 39/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0342 - accuracy: 0.9846 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 40/40
# 98/98 [==============================] - 1s 9ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000

# %%
# Image train
X_image_train = X_image_train.astype("float32")/255.0
X_image_validation = X_image_validation.astype("float32")/255.0
X_image_test = X_image_test.astype("float32")/255.0

image_input_shape = (X_image_train.shape[1:])
image_model = build_model(image_input_shape)

image_optimizer = keras.optimizers.Adam(learning_rate=0.0001)

image_model.compile(optimizer=image_optimizer,
             loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

image_model.summary()

image_history = image_model.fit(X_image_train, y_image_train, batch_size=2, epochs=40, validation_data=(X_image_validation, y_image_validation))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 46, 46, 32)        320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 46, 46, 32)        128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 44, 44, 32)        9248
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 44, 44, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 22, 22, 32)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 22, 22, 32)        128
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 20, 20, 64)        256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 18, 18, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 9, 9, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5184)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               1327360
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 480)               123360
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 480)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 1443
# =================================================================
# Total params: 1,517,795
# Trainable params: 1,517,475
# Non-trainable params: 320
# _________________________________________________________________
# Epoch 1/40
# 98/98 [==============================] - 3s 19ms/step - loss: 1.7094 - accuracy: 0.3795 - val_loss: 1.0713 - val_accuracy: 0.4286
# Epoch 2/40
# 98/98 [==============================] - 2s 17ms/step - loss: 1.3251 - accuracy: 0.4923 - val_loss: 1.1382 - val_accuracy: 0.2041
# Epoch 3/40
# 98/98 [==============================] - 2s 19ms/step - loss: 1.0951 - accuracy: 0.5436 - val_loss: 1.1625 - val_accuracy: 0.2041
# Epoch 4/40
# 98/98 [==============================] - 2s 20ms/step - loss: 0.9328 - accuracy: 0.5744 - val_loss: 1.1526 - val_accuracy: 0.4490
# Epoch 5/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8570 - accuracy: 0.6256 - val_loss: 1.1470 - val_accuracy: 0.2245
# Epoch 6/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8395 - accuracy: 0.6513 - val_loss: 1.1467 - val_accuracy: 0.4286
# Epoch 7/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7628 - accuracy: 0.6410 - val_loss: 0.8012 - val_accuracy: 0.6122
# Epoch 8/40
# 98/98 [==============================] - 2s 18ms/step - loss: 0.5840 - accuracy: 0.7282 - val_loss: 0.7965 - val_accuracy: 0.6531
# Epoch 9/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.5565 - accuracy: 0.7795 - val_loss: 0.5199 - val_accuracy: 0.7551
# Epoch 10/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.4521 - accuracy: 0.8308 - val_loss: 0.6086 - val_accuracy: 0.7143
# Epoch 11/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.4581 - accuracy: 0.8103 - val_loss: 0.6249 - val_accuracy: 0.7347
# Epoch 12/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.5155 - accuracy: 0.7897 - val_loss: 0.4428 - val_accuracy: 0.7959
# Epoch 13/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.3820 - accuracy: 0.8513 - val_loss: 0.4554 - val_accuracy: 0.7755
# Epoch 14/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.3453 - accuracy: 0.8769 - val_loss: 0.4391 - val_accuracy: 0.7959
# Epoch 15/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.3627 - accuracy: 0.8462 - val_loss: 0.2556 - val_accuracy: 0.8776
# Epoch 16/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.3899 - accuracy: 0.8462 - val_loss: 0.3293 - val_accuracy: 0.8163
# Epoch 17/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.3012 - accuracy: 0.8821 - val_loss: 0.2837 - val_accuracy: 0.8571
# Epoch 18/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2999 - accuracy: 0.8821 - val_loss: 0.4615 - val_accuracy: 0.7755
# Epoch 19/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.3372 - accuracy: 0.8667 - val_loss: 0.2679 - val_accuracy: 0.8776
# Epoch 20/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2419 - accuracy: 0.9026 - val_loss: 0.2243 - val_accuracy: 0.8980
# Epoch 21/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2646 - accuracy: 0.8821 - val_loss: 0.2043 - val_accuracy: 0.8980
# Epoch 22/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2791 - accuracy: 0.9026 - val_loss: 0.3284 - val_accuracy: 0.8163
# Epoch 23/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2891 - accuracy: 0.8923 - val_loss: 0.2372 - val_accuracy: 0.8571
# Epoch 24/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2094 - accuracy: 0.9026 - val_loss: 0.2084 - val_accuracy: 0.8980
# Epoch 25/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.1673 - accuracy: 0.9282 - val_loss: 0.1626 - val_accuracy: 0.9388
# Epoch 26/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.1380 - accuracy: 0.9436 - val_loss: 0.2070 - val_accuracy: 0.8980
# Epoch 27/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.1719 - accuracy: 0.9436 - val_loss: 0.4088 - val_accuracy: 0.8163
# Epoch 28/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2067 - accuracy: 0.9179 - val_loss: 0.5190 - val_accuracy: 0.7551
# Epoch 29/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.1775 - accuracy: 0.9385 - val_loss: 0.0821 - val_accuracy: 0.9796
# Epoch 30/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2039 - accuracy: 0.9128 - val_loss: 0.1484 - val_accuracy: 0.9388
# Epoch 31/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.0802 - accuracy: 0.9590 - val_loss: 0.0824 - val_accuracy: 0.9796
# Epoch 32/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.0796 - accuracy: 0.9846 - val_loss: 0.1158 - val_accuracy: 0.9388
# Epoch 33/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.0745 - accuracy: 0.9744 - val_loss: 0.1002 - val_accuracy: 0.9796
# Epoch 34/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.0915 - accuracy: 0.9692 - val_loss: 0.2624 - val_accuracy: 0.8980
# Epoch 35/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.1292 - accuracy: 0.9385 - val_loss: 0.1073 - val_accuracy: 0.9592
# Epoch 36/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.0910 - accuracy: 0.9641 - val_loss: 0.1512 - val_accuracy: 0.9184
# Epoch 37/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.0791 - accuracy: 0.9846 - val_loss: 0.0902 - val_accuracy: 0.9592
# Epoch 38/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.0732 - accuracy: 0.9897 - val_loss: 0.1142 - val_accuracy: 0.9592
# Epoch 39/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.1328 - accuracy: 0.9590 - val_loss: 0.0749 - val_accuracy: 0.9796
# Epoch 40/40
# 98/98 [==============================] - 2s 17ms/step - loss: 0.0840 - accuracy: 0.9538 - val_loss: 0.1490 - val_accuracy: 0.9184

# %%
#Audio Loss Curves
plt.figure(figsize=[8,6])
plt.plot(audio_history.history['loss'],'r',linewidth=3.0)
plt.plot(audio_history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Audio Loss Curves',fontsize=16)

#Image Loss Curves
plt.figure(figsize=[8,6])
plt.plot(image_history.history['loss'],'r',linewidth=3.0)
plt.plot(image_history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Image Loss Curves',fontsize=16)

#Audio Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(audio_history.history['accuracy'],'r',linewidth=3.0)
plt.plot(audio_history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Audio Accuracy Curves',fontsize=16)

#Image Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(image_history.history['accuracy'],'r',linewidth=3.0)
plt.plot(image_history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Image Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Image Accuracy Curves')

# %%
# Audio/Image test
audio_test_error, audio_test_accuracy = audio_model.evaluate(X_audio_test, y_audio_test, verbose=1)
print("Audio test set accuracy: {}%".format(audio_test_accuracy*100))
image_test_error, image_test_accuracy = image_model.evaluate(X_image_test, y_image_test, verbose=1)
print("Image test set accuracy: {}%".format(image_test_accuracy*100))
# Out:
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0036 - accuracy: 1.0000
# Audio test set accuracy: 100.0%
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3782 - accuracy: 0.9032
# Image test set accuracy: 90.32257795333862%

# %%
# Save models
audio_model.save("CNNaudioClassifier.model")
image_model.save("CNNimageClassifier.model")
# Out:
# INFO:tensorflow:Assets written to: CNNaudioClassifier.model\assets
# INFO:tensorflow:Assets written to: CNNimageClassifier.model\assets
